# %% [markdown]
# # Data Wrangling with MongoDB
#
# ### Project Overview
#
# In this project, I will take a section of the open street map dataset and perform some data cleaning.
#
# ### Map Area
#
# Denver/Boulder metro, CO
#
# ### Objectives
#
# 1. Convert xml data to json
# 2. Cleanup street names and zip codes
# 3. Move cleaned dataset to a mongoDB instance

# %% [markdown]
# ### Data Import

# %%
import xml.etree.cElementTree as ET
import pprint
import re
import codecs
import json
import collections
import pymongo
from collections import defaultdict

# %% [markdown]
# ### Creating a Sample Dataset from the Denver/Boulder Dataset
#
# Because the Denver/Boulder dataset is pretty large, I want to use a smaller section of it while I'm testing code.

# %%
OSM_FILE = "denver-boulder_colorado.osm"  
SAMPLE_FILE = "sample.osm"

k = 10 # Parameter: take every k-th top level element

def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag

    Reference:
    http://stackoverflow.com/questions/3095434/inserting-newlines-in-xml-file-generated-via-xml-etree-elementtree-in-python
    """
    context = iter(ET.iterparse(osm_file, events=('start', 'end')))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


with open(SAMPLE_FILE, 'wb') as output:
    output.write('<?xml version="1.0" encoding="UTF-8"?>\n')
    output.write('<osm>\n  ')

    # Write every kth top level element
    for i, element in enumerate(get_element(OSM_FILE)):
        if i % k == 0:
            output.write(ET.tostring(element, encoding='utf-8'))

    output.write('</osm>')

# %%
# Here I want to get a general idea of the scope of the dataset
def count_tags(filename):
        tags = {}
        for event, elem in ET.iterparse(filename):
            if elem.tag in tags: 
                tags[elem.tag] += 1
            else:
                tags[elem.tag] = 1
        return tags
den_tags = count_tags(SAMPLE_FILE)
pprint.pprint(den_tags)
# Out:
# {'member': 3714,
#  'nd': 391253,
#  'node': 336500,
#  'osm': 1,
#  'relation': 164,
#  'tag': 187336,
#  'way': 37141}

# %%
lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')


def key_type(element, keys):
    if element.tag == "tag":
        for tag in element.iter('tag'):
            k = tag.get('k')
            if lower.search(k):
                keys['lower'] += 1
            elif lower_colon.search(k):
                keys['lower_colon'] += 1
            elif problemchars.search(k):
                keys['problemchars'] += 1
            else:
                keys['other'] += 1
    return keys


def process_map(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)

    return keys

keys = process_map(SAMPLE_FILE)
pprint.pprint(keys)
# Out:
# {'lower': 111809, 'lower_colon': 71853, 'other': 3674, 'problemchars': 0}

# %%
#people invovlved in the map editing.
def unique_users(filename):
    users = set()
    for _, element in ET.iterparse(filename):
        for e in element:
            if 'uid' in e.attrib:
                users.add(e.attrib['uid'])
    return users
users = unique_users(SAMPLE_FILE)
len(users)
# Out:
# 1240

# %% [markdown]
# ### Investigating Street Names
#
# Next, I need to get a better understanding of all of the different street names used in this dataset, to see if there are inconsistencies that need to be fixed.

# %%
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)

expected = ["Avenue", "Boulevard", "Commons", "Court", "Drive", "Lane", "Parkway", 
                         "Place", "Road", "Square", "Street", "Trail"]

mapping = {'Ave'  : 'Avenue',
           'Blvd' : 'Boulevard',
           'Dr'   : 'Drive',
           'Ln'   : 'Lane',
           'Pkwy' : 'Parkway',
           'Rd'   : 'Road',
           'Rd.'   : 'Road',
           'St'   : 'Street',
           'street' :"Street",
           'st'   : "Street",
           'Ct'   : "Court",
           'Cir'  : "Circle",
           'Cr'   : "Court",
           'ave'  : 'Avenue',
           'Hwg'  : 'Highway',
           'Hwy'  : 'Highway',
           'Sq'   : "Square",
           'Raod' : "Road",}

            


def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)

def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")

def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
    return street_types

# %%
street_types = audit(SAMPLE_FILE)
pprint.pprint(dict(street_types))
# Out:
# {'119': set(['Highway 119']),
#  '19': set(['South Rock Creek Parkway, Building 19']),
#  '2': set(['Colorado SH 2', 'Colorado SR 2']),
#  '2200': set(['18th Street Suite 2200']),
#  '285': set(['Highway 285']),
#  '287': set(['US Highway 287']),
#  '52': set(['I-76 & CO Hwy 52']),
#  '72': set(['CO 72']),
#  '73': set(['Hwy 73']),
#  '74': set(['Highway 74']),
#  '83': set(['State Highway 83']),
#  '900': set(['West 120th Avenue, Suite 900']),
#  'Ave': set(['E Caley Ave',
#              'E Fair Ave',
#              'E Maplewood Ave',
#              'W Plymouth Ave',
#              'W. 10th Ave',
#              'Washington Ave']),
#  'Avenue)': set(['East Bromley Lane (152nd Avenue)']),
#  'Baselin': set(['Baselin']),
#  'Baseline': set(['Baseline']),
#  'Bikeway': set(['US 36 Bikeway']),
#  'Blvd': set(['Colorado Blvd',
#               'Green Valley Ranch Blvd',
#               'S University  Blvd',
#               'Sheridan Blvd',
#               'Wadsworth Blvd']),
#  'Broadway': set(['Broadway', 'S Broadway', 'South Broadway']),
#  'Caria': set(['Caria']),
#  'Centennial': set(['Centennial']),
#  'Center': set(['Garden Center']),
#  'Cir': set(['S Lake Cir']),
#  'Circle': set(['Adams Circle',
#                 'Adonia Circle',
#                 'Argus Circle',
#                 'Ashfield Circle',
#                 'Barberry Circle',
#                 'Bedivere Circle',
#                 'Brainard Circle',
#                 'Century Circle',
#                 'Cornwall Circle',
#                 'Cree Circle',
#                 'Cypress Circle',
#                 'Del Mar Circle',
#                 'Delos Circle',
#                 'Driftwood Circle',
#                 'Durham Circle',
#                 'Earle Circle',
#                 'East Briarwood Circle',
#                 'East Flatiron Circle',
#                 'East Mineral Circle',
#                 'East Sutton Circle',
#                 'East Warren Circle',
#                 'Essex Circle',
#                 'Euclid Circle',
#                 'Fairlawn Circle',
#                 'Fordham Circle',
#                 'Forest Park Circle',
#                 'Gateway Circle',
#                 'Goss Circle',
#                 'Greenbriar Circle',
#                 'Gunbarrel Circle',
#                 'Hercules Circle',
#                 'Hermes Circle',
#                 'Homer Circle',
#                 'Ilium Circle',
#                 'Julian Circle',
#                 'Lambert Circle',
#                 'Lincoln Circle',
#                 'Manhattan Circle',
#                 'Manorbrier Circle',
#                 'Mile High Stadium Circle',
#                 'Minotaur Circle',
#                 'Noma Circle',
#                 'Olympian Circle',
#                 'Pearl East Circle',
#                 'Rimrock Circle',
#                 'Rock Creek Circle',
#                 'Sagrimore Circle',
#                 'Scorpios Circle',
#                 'South Beech Circle',
#                 'South Nelson Circle',
#                 'South Yosemite Circle',
#                 'Squires Circle',
#                 'St. Ida Circle',
#                 'Sterling Circle',
#                 'Sunshine Circle',
#                 'Sweetwater Circle',
#                 'West 116th Circle',
#                 'West Sutton Circle']),
#  'Co-119': set(['Co-119']),
#  'Colfax': set(['East Colfax']),
#  'Crescent': set(['Interlocken Crescent']),
#  'Ct': set(['S Niagra Ct', 'South 57th Ct']),
#  'Dr': set(['Community Center Dr',
#             'Community Circle Dr',
#             'Conifer Town Denter Dr',
#             'Eisenhower Dr']),
#  'East': set(['Inverness Court East',
#               'Inverness Drive East',
#               'South Chapparal Circle East']),
#  'Elm': set(['East Elm']),
#  'K': set(['Norwood Drive Unit K']),
#  'Lamar': set(['Lamar']),
#  'Main': set(['Main']),
#  'Mainstreet': set(['East Mainstreet']),
#  'Mall': set(['Central Campus Mall']),
#  'Newland': set(['Newland']),
#  'North': set(['Nautilus Court North']),
#  'Pkwy': set(['Orchard Pkwy']),
#  'Pl': set(['E Lake Pl', 'E Maplewood Pl', 'E Orchard Pl', 'W 16th Pl']),
#  'Point': set(['Buchanan Point',
#                'High Lonesome Point',
#                'Lodgewood Point',
#                'Lone Eagle Point',
#                'Pawnee Point',
#                'Sawtooth Point']),
#  'Raod': set(['South Parker Raod']),
#  'Rd': set(['E Arapahoe Rd', 'E. Rim Rd', 'Pine Valley Rd']),
#  'Rd.': set(['E. Rim Rd.']),
#  'Row': set(['Colony Row']),
#  'South': set(['Buchtel Boulevard South',
#                'Inverness Drive South',
#                'Nautilus Court South']),
#  'St': set(['Broadway St',
#             'E Simpson St',
#             'East Evans St',
#             'Grant St',
#             'Jefferson St',
#             'Main St',
#             'S Clayton St',
#             'S Columbine St',
#             'S Elizabeth St',
#             'S Josephine St',
#             'S Newport St',
#             'S Niagra St',
#             'S Pontiac St',
#             'S Poplar St',
#             'S Quebec St',
#             'S Sherman St',
#             'South Grant St',
#             'Vine St',
#             'W Mulberry St',
#             'Wright St']),
#  'Varra': set(['Via Varra']),
#  'Way': set(['Aberdeen Way',
#              'Airport Way',
#              'Chatham Way',
#              'Del Corso Way',
#              'Devonshire Way',
#              'Durham Way',
#              'East 104th Way',
#              'East 60th Way',
#              'Golden Eagle Way',
#              'Iliad Way',
#              'Justice Way',
#              'Kincross Way',
#              'Laurel Way',
#              'Meredith Way',
#              'Progress Way',
#              'Rampart Way',
#              'Reed Way',
#              'S Ellipse Way',
#              'S Monaco Way',
#              'S Vaughn Way',
#              'South Cornerstar Way',
#              'South Dayton Way',
#              'South Fultondale Way',
#              'South Gibraltar Way',
#              'South Grand Baker Way',
#              'South Oak Hill Way',
#              'South Parkglenn Way',
#              'South Pierce Way',
#              'South Pontiac Way',
#              'South Trenton Way',
#              'South Xapary Way',
#              'Spader Way',
#              'West 68th Way',
#              'West 83rd Way',
#              'West 89th Way',
#              'Wisteria Way']),
#  'West': set(['Inverness Drive West',
#               'Park Avenue West',
#               'South Carr Avenue West',
#               'Sterling Circle West']),
#  'st': set(['28th st'])}

# %%
def update_street(name, mapping, regex):
    m = regex.search(name)
    if m:
        street_type = m.group()
        if street_type in mapping:
            name = re.sub(regex, mapping[street_type], name)
    return name

for street_type, ways in street_types.iteritems():
    for name in ways:
        new_name = update_street(name, mapping, street_type_re)
        print name, "=>", new_name
# Out:
# East Colfax => East Colfax
# Baseline => Baseline
# Caria => Caria
# South Carr Avenue West => South Carr Avenue West
# Inverness Drive West => Inverness Drive West
# Park Avenue West => Park Avenue West
# Sterling Circle West => Sterling Circle West
# Main => Main
# Via Varra => Via Varra
# E. Rim Rd => E. Rim Road
# E Arapahoe Rd => E Arapahoe Road
# Pine Valley Rd => Pine Valley Road
# Newland => Newland
# S Niagra Ct => S Niagra Court
# South 57th Ct => South 57th Court
# Devonshire Way => Devonshire Way
# East 60th Way => East 60th Way
# South Xapary Way => South Xapary Way
# South Fultondale Way => South Fultondale Way
# Justice Way => Justice Way
# Airport Way => Airport Way
# S Monaco Way => S Monaco Way
# Golden Eagle Way => Golden Eagle Way
# South Grand Baker Way => South Grand Baker Way
# Reed Way => Reed Way
# South Dayton Way => South Dayton Way
# Wisteria Way => Wisteria Way
# Aberdeen Way => Aberdeen Way
# West 68th Way => West 68th Way
# Kincross Way => Kincross Way
# Progress Way => Progress Way
# Meredith Way => Meredith Way
# West 83rd Way => West 83rd Way
# S Vaughn Way => S Vaughn Way
# South Pierce Way => South Pierce Way
# South Cornerstar Way => South Cornerstar Way
# Iliad Way => Iliad Way
# South Oak Hill Way => South Oak Hill Way
# Laurel Way => Laurel Way
# S Ellipse Way => S Ellipse Way
# Chatham Way => Chatham Way
# South Trenton Way => South Trenton Way
# Spader Way => Spader Way
# South Pontiac Way => South Pontiac Way
# West 89th Way => West 89th Way
# Rampart Way => Rampart Way
# South Parkglenn Way => South Parkglenn Way
# Durham Way => Durham Way
# Del Corso Way => Del Corso Way
# East 104th Way => East 104th Way
# South Gibraltar Way => South Gibraltar Way
# State Highway 83 => State Highway 83
# Minotaur Circle => Minotaur Circle
# Durham Circle => Durham Circle
# South Yosemite Circle => South Yosemite Circle
# Gateway Circle => Gateway Circle
# Cree Circle => Cree Circle
# Scorpios Circle => Scorpios Circle
# Ilium Circle => Ilium Circle
# Century Circle => Century Circle
# Cornwall Circle => Cornwall Circle
# Noma Circle => Noma Circle
# Essex Circle => Essex Circle
# Earle Circle => Earle Circle
# Rimrock Circle => Rimrock Circle
# Adams Circle => Adams Circle
# Driftwood Circle => Driftwood Circle
# South Beech Circle => South Beech Circle
# Lincoln Circle => Lincoln Circle
# Homer Circle => Homer Circle
# South Nelson Circle => South Nelson Circle
# East Briarwood Circle => East Briarwood Circle
# Ashfield Circle => Ashfield Circle
# East Mineral Circle => East Mineral Circle
# Goss Circle => Goss Circle
# Barberry Circle => Barberry Circle
# Olympian Circle => Olympian Circle
# Argus Circle => Argus Circle
# Lambert Circle => Lambert Circle
# East Sutton Circle => East Sutton Circle
# West Sutton Circle => West Sutton Circle
# Hermes Circle => Hermes Circle
# Brainard Circle => Brainard Circle
# Pearl East Circle => Pearl East Circle
# Adonia Circle => Adonia Circle
# Cypress Circle => Cypress Circle
# Sunshine Circle => Sunshine Circle
# Euclid Circle => Euclid Circle
# Manhattan Circle => Manhattan Circle
# East Warren Circle => East Warren Circle
# Hercules Circle => Hercules Circle
# Greenbriar Circle => Greenbriar Circle
# East Flatiron Circle => East Flatiron Circle
# Sterling Circle => Sterling Circle
# Rock Creek Circle => Rock Creek Circle
# St. Ida Circle => St. Ida Circle
# Fairlawn Circle => Fairlawn Circle
# Squires Circle => Squires Circle
# Gunbarrel Circle => Gunbarrel Circle
# West 116th Circle => West 116th Circle
# Sweetwater Circle => Sweetwater Circle
# Delos Circle => Delos Circle
# Mile High Stadium Circle => Mile High Stadium Circle
# Forest Park Circle => Forest Park Circle
# Manorbrier Circle => Manorbrier Circle
# Del Mar Circle => Del Mar Circle
# Bedivere Circle => Bedivere Circle
# Julian Circle => Julian Circle
# Sagrimore Circle => Sagrimore Circle
# Fordham Circle => Fordham Circle
# US 36 Bikeway => US 36 Bikeway
# Highway 119 => Highway 119
# E Lake Pl => E Lake Pl
# E Orchard Pl => E Orchard Pl
# E Maplewood Pl => E Maplewood Pl
# W 16th Pl => W 16th Pl
# 18th Street Suite 2200 => 18th Street Suite 2200
# Lamar => Lamar
# E. Rim Rd. => E. Rim Road
# Nautilus Court North => Nautilus Court North
# East Elm => East Elm
# Colorado SH 2 => Colorado SH 2
# Colorado SR 2 => Colorado SR 2
# South Chapparal Circle East => South Chapparal Circle East
# Inverness Drive East => Inverness Drive East
# Inverness Court East => Inverness Court East
# South Parker Raod => South Parker Road
# I-76 & CO Hwy 52 => I-76 & CO Hwy 52
# Community Circle Dr => Community Circle Drive
# Eisenhower Dr => Eisenhower Drive
# Conifer Town Denter Dr => Conifer Town Denter Drive
# Community Center Dr => Community Center Drive
# US Highway 287 => US Highway 287
# Centennial => Centennial
# East Bromley Lane (152nd Avenue) => East Bromley Lane (152nd Avenue)
# Garden Center => Garden Center
# East Mainstreet => East Mainstreet
# Norwood Drive Unit K => Norwood Drive Unit K
# S Sherman St => S Sherman Street
# Broadway St => Broadway Street
# Vine St => Vine Street
# S Clayton St => S Clayton Street
# W Mulberry St => W Mulberry Street
# S Quebec St => S Quebec Street
# Wright St => Wright Street
# South Grant St => South Grant Street
# S Poplar St => S Poplar Street
# East Evans St => East Evans Street
# E Simpson St => E Simpson Street
# S Pontiac St => S Pontiac Street
# Jefferson St => Jefferson Street
# S Newport St => S Newport Street
# S Elizabeth St => S Elizabeth Street
# S Niagra St => S Niagra Street
# S Josephine St => S Josephine Street
# S Columbine St => S Columbine Street
# Main St => Main Street
# Grant St => Grant Street
# S Lake Cir => S Lake Circle
# Central Campus Mall => Central Campus Mall
# Highway 74 => Highway 74
# Hwy 73 => Hwy 73
# CO 72 => CO 72
# Broadway => Broadway
# S Broadway => S Broadway
# South Broadway => South Broadway
# Orchard Pkwy => Orchard Parkway
# Nautilus Court South => Nautilus Court South
# Buchtel Boulevard South => Buchtel Boulevard South
# Inverness Drive South => Inverness Drive South
# Co-119 => Co-119
# West 120th Avenue, Suite 900 => West 120th Avenue, Suite 900
# Lone Eagle Point => Lone Eagle Point
# Pawnee Point => Pawnee Point
# Buchanan Point => Buchanan Point
# Lodgewood Point => Lodgewood Point
# Sawtooth Point => Sawtooth Point
# High Lonesome Point => High Lonesome Point
# South Rock Creek Parkway, Building 19 => South Rock Creek Parkway, Building 19
# Highway 285 => Highway 285
# 28th st => 28th Street
# Interlocken Crescent => Interlocken Crescent
# Wadsworth Blvd => Wadsworth Boulevard
# Sheridan Blvd => Sheridan Boulevard
# S University  Blvd => S University  Boulevard
# Colorado Blvd => Colorado Boulevard
# Green Valley Ranch Blvd => Green Valley Ranch Boulevard
# W. 10th Ave => W. 10th Avenue
# W Plymouth Ave => W Plymouth Avenue
# Washington Ave => Washington Avenue
# E Caley Ave => E Caley Avenue
# E Maplewood Ave => E Maplewood Avenue
# E Fair Ave => E Fair Avenue
# Colony Row => Colony Row
# Baselin => Baselin

# %%
zip_code_range = [80000,81000]
zip_code_default = 80203

def audit_zipcode(invalid_zipcodes, zipcode):
    try:
        if not (zip_code_range[0] <= int(zipcode) <= zip_code_range[1]):
            raise ValueError
    except ValueError:
        invalid_zipcodes[zipcode] += 1
        
def is_zipcode(elem):
    return (elem.attrib['k'] == "addr:postcode")

def audit_zip(osmfile):
    osm_file = open(osmfile, "r")
    invalid_zipcodes = defaultdict(int)
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_zipcode(tag):
                    audit_zipcode(invalid_zipcodes,tag.attrib['v'])

    return invalid_zipcodes

invalid_zipcode = audit_zip(SAMPLE_FILE)
pprint.pprint(dict(invalid_zipcode))
# Out:
# {'1800': 1,
#  '80010-1425': 1,
#  '801112': 1,
#  '80214-1803': 1,
#  '80214-1833': 1,
#  '80219-1535': 1,
#  '80226-2975': 1,
#  '80229-7923': 1,
#  '80303-1229': 1,
#  '80503-7570': 1,
#  '80504-6311': 1,
#  '80504-8601': 1,
#  'CO': 1,
#  'CO 80211': 1,
#  'CO 80305': 1,
#  'CO 80439': 1,
#  'Golden, CO 80401': 1}

# %%
def update_zip(zipcode):
    try:
        if not (zip_code_range[0] <= int(zipcode) <= zip_code_range[1]):
            raise ValueError
        else:
            return int(zipcode)
    except ValueError:
        return zip_code_default

# %%
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)
lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

CREATED = [ "version", "changeset", "timestamp", "user", "uid"]


def shape_element(e):
    node = {}
    node['created'] = {}
    node['pos'] = [0,0]
    if e.tag == "way":
        node['node_refs'] = []
    if e.tag == "node" or e.tag == "way" :
        node['type'] = e.tag
        #attributes
        for k, v in e.attrib.iteritems():
            #latitude
            if k == 'lat':
                try:
                    lat = float(v)
                    node['pos'][0] = lat
                except ValueError:
                    pass
            #longitude
            elif k == 'lon':
                try:
                    lon = float(v)
                    node['pos'][1] = lon
                except ValueError:
                    pass
            #creation metadata
            elif k in CREATED:
                node['created'][k] = v
            else:
                node[k] = v
        #children
        for tag in e.iter('tag'):
            k = tag.attrib['k']
            v = tag.attrib['v']
            if problemchars.match(k):
                continue
            elif lower_colon.match(k):
                k_split = k.split(':')
                #address fields
                if k_split[0] == 'addr':
                    k_item = k_split[1]
                    if 'address' not in node:
                        node['address'] = {}
                    #streets
                    if k_item == 'street':
                        v = update_street(v, mapping, street_type_re)                    
                    #postal codes
                    if k_item == 'postcode':
                        v = update_zip(v)
                    node['address'][k_item] = v
                    continue
            node[k] = v
        #way children
        if e.tag == "way":
            for n in e.iter('nd'):
                ref = n.attrib['ref']
                node['node_refs'].append(ref);
        return node
    else:
        return None


def process_map(file_in, pretty = False):
    file_out = "{0}.json".format(file_in)
    data = []
    with codecs.open(file_out, "w") as fo:
        for _, element in ET.iterparse(file_in):
            el = shape_element(element)
            if el:
                data.append(el)
                if pretty:
                    fo.write(json.dumps(el, indent=2)+"\n")
                else:
                    fo.write(json.dumps(el) + "\n")
    return data

# %%
'''
PROCESS DATA AND OUTPUT JSON
'''
process_map(SAMPLE_FILE, False)
# Out:
# [{'created': {'changeset': '7551724',
#    'timestamp': '2011-03-14T04:12:27Z',
#    'uid': '117055',
#    'user': 'GPS_dr',
#    'version': '6'},
#   'id': '25676629',
#   'pos': [39.9822661, -105.2638756],
#   'type': 'node'},
#  {'created': {'changeset': '209539',
#    'timestamp': '2007-02-06T20:35:37Z',
#    'uid': '5879',
#    'user': 'erinn',
#    'version': '1'},
#   'id': '25689364',
#   'pos': [39.9816945, -105.261765],
#   'type': 'node'},
#  {'created': {'changeset': '15013106',
#    'timestamp': '2013-02-13T00:22:23Z',
#    'uid': '1209932',
#    'user': 'oddityoverseer',
#    'version': '3'},
#   'id': '25696400',
#   'pos': [40.0035047, -105.2624665],
#   'type': 'node'},
#  {'created': {'changeset': '1918371',
#    'timestamp': '2009-07-23T19:31:25Z',
#    'uid': '1679',
#    'user': 'andrewpmk',
#    'version': '2'},
#   'id': '25757811',
#   'pos': [40.0073148, -105.2534844],
#   'type': 'node'},
#  {'created': {'changeset': '27947599',
#    'timestamp': '2015-01-06T04:34:31Z',
#    'uid': '2237750',
#    'user': 'chachafish',
#    'version': '4'},
#   'id': '25765918',
#   'pos': [40.018436, -105.2773526],
#   'type': 'node'},
#  {'created': {'changeset': '220842',
#    'timestamp': '2007-02-21T05:39:30Z',
#    'uid': '5879',
#    'user': 'erinn',
#    'version': '1'},
#   'id': '26050274',
#   'pos': [39.9601621, -105.2000852],
#   'type': 'node'},
#  {'created': {'changeset': '15626754',
#    'timestamp': '2013-04-06T00:23:52Z',
#    'uid': '1209932',
#    'user': 'oddityoverseer',
#    'version': '3'},
#   'id': '26165217',
#   'pos': [40.0083414, -105.2614266],
#   'type': 'node'},
#  {'created': {'changeset': '28505237',
#    'timestamp': '2015-01-30T13:50:58Z',
#    'uid': '2237750',
#    'user': 'chachafish',
#    'version': '4'},
#   'id': '26251285',
#   'pos': [39.8828802, -105.0689213],
#   'type': 'node'},
#  {'created': {'changeset': '226391',
#    'timestamp': '2007-03-01T06:28:16Z',
#    'uid': '5879',
#    'user': 'erinn',
#    'version': '1'},
#   'id': '26258824',
#   'pos': [40.1126349, -105.2589717],
#   'type': 'node'},
#  {'created': {'changeset': '32337756',
#    'timestamp': '2015-07-01T18:08:29Z',
#    'uid': '2226712',
#    'user': 'dannykath',
#    'version': '2'},
#   'id': '26259734',
#   'pos': [40.0606897, -105.2763322],
#   'type': 'node'},
#  {'created': {'changeset': '7570428',
#    'timestamp': '2011-03-15T21:58:50Z',
#    'uid': '117055',
#    'user': 'GPS_dr',
#    'version': '2'},
#   'id': '26259837',
#   'pos': [40.0281078, -105.23366],
#   'type': 'node'},
#  {'created': {'changeset': '237698',
#    'timestamp': '2007-03-17T06:04:25Z',
#    'uid': '5879',
#    'user': 'erinn',
#    'version': '1'},
#   'created_by': 'YahooApplet 1.0',
#   'id': '26579912',
#   'pos': [40.0301083, -105.2782407],
#   'type': 'node'},
#  {'created': {'changeset': '29896591',
#    'timestamp': '2015-04-01T06:53:43Z',
#    'uid': '227972',
#    'user': 'Your Village Maps',
#    'version': '6'},
#   'id': '27512376',
#   'pos': [39.7319516, -105.0158714],
#   'type': 'node'},
#  {'created': {'changeset': '29867631',
#    'timestamp': '2015-03-31T04:53:44Z',
#    'uid': '227972',
#    'user': 'Your Village Maps',
#    'version': '7'},
#   'id': '27512399',
#   'pos': [39.7216501, -105.0091366],
#   'type': 'node'},
#  {'created': {'changeset': '21967995',
#    'timestamp': '2014-04-27T04:01:19Z',
#    'uid': '227972',
#    'user': 'Your Village Maps',
#    'version': '8'},
#   'id': '27512441',
#   'pos': [39.7030566, -104.9904804],
#   'type': 'node'},
#  {'created': {'changeset': '1900747',
#    'timestamp': '2009-07-22T04:35:32Z',
#    'uid': '139555',
#    'user': 'DavidJDBA',
#    'version': '4'},
#   'id': '27548626',
#   'pos': [39.69126, -104.9760243],
#   'type': 'node'},
#  {'created': {'changeset': '30925804',
#    'timestamp': '2015-05-09T05:55:17Z',
#    'uid': '227972',
#    'user': 'Your Village Maps',
#    'version': '18'},
#   'id': '27548650',
#   'pos': [39.684704, -104.9599863],
#   'type': 'node'},
#  {'created': {'changeset': '23346',
#    'timestamp': '2007-04-23T02:48:22Z',
#    'uid': '5879',
#    'user': 'erinn',
#    'version': '1'},
#   'created_by': 'YahooApplet 1.0',
#   'id': '27548698',
#   'pos': [39.6695022, -104.9270897],
#   'type': 'node'},
#  {'created': {'changeset': '2040795',
#    'timestamp': '2009-08-04T23:58:09Z',
#    'uid': '139555',
#    'user': 'DavidJDBA',
#    'version': '3'},
#   'id': '31926222',
#   'pos': [39.5645373, -104.8713063],
#   'type': 'node'},
#  {'created': {'changeset': '4013292',
#    'timestamp': '2010-03-01T22:42:30Z',
#    'uid': '161206',
#    'user': 'SK53_bulk',
#    'version': '2'},
#   'id': '32191222',
#   'pos': [40.0775207, -105.3922838],
#   'type': 'node'},
#  {'created': {'changeset': '24576163',
#    'timestamp': '2014-08-06T13:46:56Z',
#    'uid': '2103318',
#    'user': 'jjyach',
#    'version': '6'},
#   'id': '32269784',
#   'pos': [39.5294506, -104.7827844],
#   'type': 'node'},
#  {'created': {'changeset': '35285036',
#    'timestamp': '2015-11-13T14:13:57Z',
#    'uid': '2103318',
#    'user': 'jjyach',
#    'version': '7'},
#   'id': '32269795',
#   'pos': [39.5350208, -104.7826012],
#   'type': 'node'},
#  {'created': {'changeset': '24463511',
#    'timestamp': '2014-07-31T14:04:17Z',
#    'uid': '2103318',
#    'user': 'jjyach',
#    'version': '5'},
#   'id': '32269806',
#   'pos': [39.5380698, -104.7810876],
#   'type': 'node'},
#  {'created': {'changeset': '37819665',
#    'timestamp': '2016-03-14T12:32:47Z',
#    'uid': '2103318',
#    'user': 'jjyach',
#    'version': '5'},
#   'id': '32269818',
#   'pos': [39.5463763, -104.7796984],
#   'type': 'node'},
#  {'created': {'changeset': '7581936',
#    'timestamp': '2011-03-17T05:34:15Z',
#    'uid': '117055',
#    'user': 'GPS_dr',
#    'version': '4'},
#   'id': '32269829',
#   'pos': [39.5493949, -104.783015],
#   'type': 'node'},
#  {'created': {'changeset': '7581936',
#    'timestamp': '2011-03-17T05:25:00Z',
#    'uid': '117055',
#    'user': 'GPS_dr',
#    'version': '4'},
#   'id': '32269840',
#   'pos': [39.5522522, -104.7875368],
#   'type': 'node'},
#  {'created': {'changeset': '7581936',
#    'timestamp': '2011-03-17T05:25:00Z',
#    'uid': '117055',
#    'user': 'GPS_dr',
#    'version': '4'},
#   'id': '32269853',
#   'pos': [39.5564606, -104.787166],
#   'type': 'node'},
#  {'created': {'changeset': '2477536',
#    'timestamp': '2009-09-14T06:33:45Z',
#    'uid': '117055',
#    'user': 'GPS_dr',
#    'version': '2'},
#   'id': '32269863',
#   'pos': [39.5615619, -104.7898099],
#   'type': 'node'},
#  {'created': {'changeset': '7912258',
#    'timestamp': '2011-04-20T02:48:40Z',
#    'uid': '117055',
#    'user': 'GPS_dr',
#    'version': '4'},
#   'id': '32269890',
#   'pos': [39.5685373, -104.7950459],
#   'type': 'node'},
#  {'created': {'changeset': '4013292',
#    'timestamp': '2010-03-01T22:42:30Z',
#    'uid': '161206',
#    'user': 'SK53_bulk',
#    'version': '2'},
#   'id': '32271854',
#   'pos': [40.0774114, -105.389114],
#   'type': 'node'},
#  {'created': {'changeset': '153083',
#    'timestamp': '2007-07-19T06:59:11Z',
#    'uid': '4727',
#    'user': 'WolfMan',
#    'version': '1'},
#   'id': '32277711',
#   'pos': [40.0747549, -105.5065704],
#   'type': 'node'},
#  {'created': {'changeset': '153083',
#    'timestamp': '2007-07-19T06:59:11Z',
#    'uid': '4727',
#    'user': 'WolfMan',
#    'version': '1'},
#   'id': '32277721',
#   'pos': [40.074131, -105.5065447],
#   'type': 'node'},
#  {'created': {'changeset': '28961205',
#    'timestamp': '2015-02-19T17:36:50Z',
#    'uid': '2226712',
#    'user': 'dannykath',
#    'version': '2'},
#   'id': '32277731',
#   'pos': [40.0715251, -105.5068084],
#   'type': 'node'},
#  {'created': {'changeset': '153083',
#    'timestamp': '2007-07-19T06:59:11Z',
#    'uid': '4727',
#    'user': 'WolfMan',
#    'version': '1'},
#   'id': '32277741',
#   'pos': [40.0683247, -105.5042959],
#   'type': 'node'},
#  {'created': {'changeset': '153083',
#    'timestamp': '2007-07-19T06:59:11Z',
#    'uid': '4727',
#    'user': 'WolfMan',
#    'version': '1'},
#   'id': '32277751',
#   'pos': [40.0649813, -105.5017553],
#   'type': 'node'},
#  {'created': {'changeset': '153083',
#    'timestamp': '2007-07-19T06:59:11Z',
#    'uid': '4727',
#    'user': 'WolfMan',
#    'version': '1'},
#   'id': '32277761',
#   'pos': [40.0613421, -105.4992319],
#   'type': 'node'},
#  {'created': {'changeset': '153888',
#    'timestamp': '2007-07-19T19:30:10Z',
#    'uid': '4727',
#    'user': 'WolfMan',
#    'version': '1'},
#   'id': '32277771',
#   'pos': [40.0577225, -105.5014979],
#   'type': 'node'},
#  {'created': {'changeset': '153167',
#    'timestamp': '2007-07-19T17:01:37Z',
#    'uid': '4727',
#    'user': 'WolfMan',
#    'version': '1'},
#   'id': '32324823',
#   'pos': [39.9302942, -105.1028315],
#   'type': 'node'},
#  {'created': {'changeset': '3338276',
#    'timestamp': '2009-12-09T23:44:18Z',
#    'uid': '117055',
#    'user': 'GPS_dr',
#    'version': '2'},
#   'id': '32325425',
#   'pos': [39.9310345, -105.1051486],
#   'type': 'node'},
#  {'created': {'changeset': '3338276',
#    'timestamp': '2009-12-09T23:35:38Z',
#    'uid': '117055',
#    'user': 'GPS_dr',
#    'version': '2'},
#   'id': '32329295',
#   'pos': [39.9343458, -105.0957126],
#   'type': 'node'},
#  {'created': {'changeset': '3338276',
#    'timestamp': '2009-12-09T23:35:39Z',
#    'uid': '117055',
#    'user': 'GPS_dr',
#    'version': '2'},
#   'id': '32329329',
#   'pos': [39.9309255, -105.0982688],
#   'type': 'node'},
#  {'created': {'changeset': '3338276',
#    'timestamp': '2009-12-09T23:35:27Z',
#    'uid': '117055',
#    'user': 'GPS_dr',
#    'version': '2'},
#   'id': '32329344',
#   'pos': [39.9291978, -105.0994168],
#   'type': 'node'},
#  {'created': {'changeset': '153888',
#    'timestamp': '2007-07-19T18:39:44Z',
#    'uid': '4727',
#    'user': 'WolfMan',
#    'version': '1'},
#   'id': '32329361',
#   'pos': [39.9294254, -105.1035181],
#   'type': 'node'},
#  {'created': {'changeset': '4094804',
#    'timestamp': '2010-03-11T01:39:34Z',
#    'uid': '139555',
#    'user': 'DavidJDBA',
#    'version': '2'},
#   'id': '32333777',
#   'pos': [39.9325099, -105.1198887],
#   'type': 'node'},
#  {'created': {'changeset': '4094804',
#    'timestamp': '2010-03-11T01:36:28Z',
#    'uid': '139555',
#    'user': 'DavidJDBA',
#    'version': '2'},
#   'id': '32333792',
#   'pos': [39.9296078, -105.1155248],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T04:57:08Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50822858',
#   'pos': [40.30979, -105.197637],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T04:57:08Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50822880',
#   'pos': [40.308078, -105.197585],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T04:57:09Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50822904',
#   'pos': [40.30407, -105.197685],
#   'type': 'node'},
#  {'created': {'changeset': '2488126',
#    'timestamp': '2009-09-15T04:20:36Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50822921',
#   'pos': [40.301624, -105.19932],
#   'type': 'node'},
#  {'created': {'changeset': '3106555',
#    'timestamp': '2009-11-13T15:12:24Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50822940',
#   'pos': [40.299084, -105.199748],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T04:57:11Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50823030',
#   'pos': [40.303223, -105.134775],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T04:57:11Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50823047',
#   'pos': [40.302491, -105.133144],
#   'type': 'node'},
#  {'created': {'changeset': '2488126',
#    'timestamp': '2009-09-15T04:20:37Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50823061',
#   'pos': [40.303786, -105.132443],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T04:57:18Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50823808',
#   'pos': [40.312788, -105.644509],
#   'type': 'node'},
#  {'created': {'changeset': '2963453',
#    'timestamp': '2009-10-27T08:58:20Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50823826',
#   'pos': [40.31249, -105.646022],
#   'type': 'node'},
#  {'created': {'changeset': '37072868',
#    'timestamp': '2016-02-08T05:39:02Z',
#    'uid': '16703',
#    'user': 'joelholdsworth',
#    'version': '4'},
#   'id': '50823863',
#   'pos': [40.3118707, -105.6421446],
#   'type': 'node'},
#  {'created': {'changeset': '37072868',
#    'timestamp': '2016-02-08T05:39:02Z',
#    'uid': '16703',
#    'user': 'joelholdsworth',
#    'version': '4'},
#   'id': '50823879',
#   'pos': [40.3125781, -105.6405777],
#   'type': 'node'},
#  {'created': {'changeset': '37072868',
#    'timestamp': '2016-02-08T05:39:03Z',
#    'uid': '16703',
#    'user': 'joelholdsworth',
#    'version': '4'},
#   'id': '50823922',
#   'pos': [40.3120401, -105.6404058],
#   'type': 'node'},
#  {'created': {'changeset': '37072868',
#    'timestamp': '2016-02-08T05:39:03Z',
#    'uid': '16703',
#    'user': 'joelholdsworth',
#    'version': '4'},
#   'id': '50823945',
#   'pos': [40.3108589, -105.6418581],
#   'type': 'node'},
#  {'created': {'changeset': '37072868',
#    'timestamp': '2016-02-08T05:39:03Z',
#    'uid': '16703',
#    'user': 'joelholdsworth',
#    'version': '4'},
#   'id': '50823969',
#   'pos': [40.3097419, -105.6431027],
#   'type': 'node'},
#  {'created': {'changeset': '37072868',
#    'timestamp': '2016-02-08T05:39:03Z',
#    'uid': '16703',
#    'user': 'joelholdsworth',
#    'version': '4'},
#   'id': '50823992',
#   'pos': [40.3080991, -105.6432603],
#   'type': 'node'},
#  {'created': {'changeset': '37072868',
#    'timestamp': '2016-02-08T05:39:03Z',
#    'uid': '16703',
#    'user': 'joelholdsworth',
#    'version': '4'},
#   'id': '50824005',
#   'pos': [40.3087764, -105.6429916],
#   'type': 'node'},
#  {'created': {'changeset': '37072868',
#    'timestamp': '2016-02-08T05:39:04Z',
#    'uid': '16703',
#    'user': 'joelholdsworth',
#    'version': '4'},
#   'id': '50824024',
#   'pos': [40.3093855, -105.6419691],
#   'type': 'node'},
#  {'created': {'changeset': '37072868',
#    'timestamp': '2016-02-08T05:39:04Z',
#    'uid': '16703',
#    'user': 'joelholdsworth',
#    'version': '4'},
#   'id': '50824042',
#   'pos': [40.3102977, -105.6410755],
#   'type': 'node'},
#  {'created': {'changeset': '37072868',
#    'timestamp': '2016-02-08T05:39:04Z',
#    'uid': '16703',
#    'user': 'joelholdsworth',
#    'version': '4'},
#   'id': '50824063',
#   'pos': [40.3115805, -105.6390829],
#   'type': 'node'},
#  {'created': {'changeset': '37072868',
#    'timestamp': '2016-02-08T05:39:04Z',
#    'uid': '16703',
#    'user': 'joelholdsworth',
#    'version': '4'},
#   'id': '50824080',
#   'pos': [40.3114685, -105.6384321],
#   'type': 'node'},
#  {'created': {'changeset': '37072868',
#    'timestamp': '2016-02-08T05:39:04Z',
#    'uid': '16703',
#    'user': 'joelholdsworth',
#    'version': '4'},
#   'id': '50824098',
#   'pos': [40.3098464, -105.6395945],
#   'type': 'node'},
#  {'created': {'changeset': '37072868',
#    'timestamp': '2016-02-08T05:39:04Z',
#    'uid': '16703',
#    'user': 'joelholdsworth',
#    'version': '4'},
#   'id': '50824117',
#   'pos': [40.3097865, -105.6388626],
#   'type': 'node'},
#  {'created': {'changeset': '37072868',
#    'timestamp': '2016-02-08T05:39:04Z',
#    'uid': '16703',
#    'user': 'joelholdsworth',
#    'version': '4'},
#   'id': '50824133',
#   'pos': [40.3105261, -105.6370088],
#   'type': 'node'},
#  {'created': {'changeset': '37072868',
#    'timestamp': '2016-02-08T05:39:05Z',
#    'uid': '16703',
#    'user': 'joelholdsworth',
#    'version': '4'},
#   'id': '50824154',
#   'pos': [40.3116597, -105.6363022],
#   'type': 'node'},
#  {'created': {'changeset': '37072868',
#    'timestamp': '2016-02-08T05:39:05Z',
#    'uid': '16703',
#    'user': 'joelholdsworth',
#    'version': '4'},
#   'id': '50824169',
#   'pos': [40.3127238, -105.6369886],
#   'type': 'node'},
#  {'created': {'changeset': '3106555',
#    'timestamp': '2009-11-13T15:12:35Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50826371',
#   'pos': [40.27128, -105.167375],
#   'type': 'node'},
#  {'created': {'changeset': '2963453',
#    'timestamp': '2009-10-27T08:58:31Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50826492',
#   'pos': [40.312764, -105.168932],
#   'type': 'node'},
#  {'created': {'changeset': '3106555',
#    'timestamp': '2009-11-13T15:12:35Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50826506',
#   'pos': [40.312495, -105.167995],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T04:57:52Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50826611',
#   'pos': [40.312141, -105.209895],
#   'type': 'node'},
#  {'created': {'changeset': '2488126',
#    'timestamp': '2009-09-15T04:20:49Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50826630',
#   'pos': [40.309517, -105.210322],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T04:57:53Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50826653',
#   'pos': [40.308194, -105.210776],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T04:57:53Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50826679',
#   'pos': [40.307665, -105.211634],
#   'type': 'node'},
#  {'created': {'changeset': '3106555',
#    'timestamp': '2009-11-13T15:12:36Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50826699',
#   'pos': [40.306052, -105.211148],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T04:58:09Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50827731',
#   'pos': [40.293805, -105.059177],
#   'type': 'node'},
#  {'created': {'changeset': '2963453',
#    'timestamp': '2009-10-27T08:58:38Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50827750',
#   'pos': [40.2937, -105.060369],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T04:58:09Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50827766',
#   'pos': [40.293082, -105.062088],
#   'type': 'node'},
#  {'created': {'changeset': '2963453',
#    'timestamp': '2009-10-27T08:58:38Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50827784',
#   'pos': [40.292501, -105.062403],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T04:58:10Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50827801',
#   'pos': [40.291612, -105.064666],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T04:59:11Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50831408',
#   'pos': [40.28915, -105.409209],
#   'type': 'node'},
#  {'created': {'changeset': '2488126',
#    'timestamp': '2009-09-15T04:21:08Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50831423',
#   'pos': [40.288478, -105.398418],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T04:59:12Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50831440',
#   'pos': [40.289059, -105.391593],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T04:59:12Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50831459',
#   'pos': [40.289615, -105.382137],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:00:03Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50836703',
#   'pos': [40.285147, -105.124838],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:00:11Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50838618',
#   'pos': [40.308638, -105.291394],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:01:24Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50845512',
#   'pos': [40.285889, -105.079392],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:01:25Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50845532',
#   'pos': [40.287041, -105.075621],
#   'type': 'node'},
#  {'created': {'changeset': '2963453',
#    'timestamp': '2009-10-27T08:59:52Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50848218',
#   'pos': [40.279297, -105.130294],
#   'type': 'node'},
#  {'created': {'changeset': '3106555',
#    'timestamp': '2009-11-13T15:13:50Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50855961',
#   'pos': [40.301774, -105.182456],
#   'type': 'node'},
#  {'created': {'changeset': '2963453',
#    'timestamp': '2009-10-27T09:00:14Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50855988',
#   'pos': [40.302259, -105.249879],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:03:48Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50856003',
#   'pos': [40.301343, -105.247606],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:03:48Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50856025',
#   'pos': [40.300213, -105.246521],
#   'type': 'node'},
#  {'created': {'changeset': '2488126',
#    'timestamp': '2009-09-15T04:22:10Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50856045',
#   'pos': [40.299636, -105.24663],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:03:49Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50856062',
#   'pos': [40.299346, -105.24574],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:03:50Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50856087',
#   'pos': [40.298833, -105.24625],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:03:50Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50856110',
#   'pos': [40.297323, -105.245929],
#   'type': 'node'},
#  {'created': {'changeset': '3106555',
#    'timestamp': '2009-11-13T15:13:50Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50856130',
#   'pos': [40.296522, -105.245717],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:03:51Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50856151',
#   'pos': [40.29039, -105.184736],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:03:51Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50856164',
#   'pos': [40.290417, -105.186261],
#   'type': 'node'},
#  {'created': {'changeset': '3106555',
#    'timestamp': '2009-11-13T15:13:50Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50856183',
#   'pos': [40.29147, -105.197069],
#   'type': 'node'},
#  {'created': {'changeset': '2488126',
#    'timestamp': '2009-09-15T04:22:11Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50856202',
#   'pos': [40.291066, -105.196696],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:03:52Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50856218',
#   'pos': [40.291987, -105.196518],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:03:52Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50856237',
#   'pos': [40.291739, -105.196253],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:03:52Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50856258',
#   'pos': [40.290576, -105.194918],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:03:53Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50856277',
#   'pos': [40.290484, -105.194311],
#   'type': 'node'},
#  {'created': {'changeset': '2488126',
#    'timestamp': '2009-09-15T04:22:11Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50856291',
#   'pos': [40.291248, -105.194179],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:03:54Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50856308',
#   'pos': [40.292301, -105.193731],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:03:54Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50856337',
#   'pos': [40.289403, -105.197476],
#   'type': 'node'},
#  {'created': {'changeset': '3664638',
#    'timestamp': '2010-01-20T08:02:11Z',
#    'uid': '117055',
#    'user': 'GPS_dr',
#    'version': '3'},
#   'id': '50858073',
#   'pos': [40.2744552, -105.1178334],
#   'type': 'node'},
#  {'created': {'changeset': '31239139',
#    'timestamp': '2015-05-17T20:52:59Z',
#    'uid': '1061145',
#    'user': 'UE_Su',
#    'version': '3'},
#   'id': '50860499',
#   'pos': [40.2958738, -105.2968218],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:05:17Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50861896',
#   'pos': [40.27217, -105.4278],
#   'type': 'node'},
#  {'created': {'changeset': '31239139',
#    'timestamp': '2015-05-17T20:53:00Z',
#    'uid': '1061145',
#    'user': 'UE_Su',
#    'version': '3'},
#   'id': '50862251',
#   'pos': [40.2856935, -105.2719642],
#   'type': 'node'},
#  {'created': {'changeset': '2488126',
#    'timestamp': '2009-09-15T04:22:51Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50863689',
#   'pos': [40.312674, -105.217493],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:06:17Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50865047',
#   'pos': [40.278852, -105.546522],
#   'type': 'node'},
#  {'created': {'changeset': '28786338',
#    'timestamp': '2015-02-12T00:22:05Z',
#    'uid': '994480',
#    'user': 'Mark Newnham',
#    'version': '3'},
#   'id': '50865080',
#   'pos': [40.2677568, -105.5399909],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:06:18Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50865091',
#   'pos': [40.267061, -105.539816],
#   'type': 'node'},
#  {'created': {'changeset': '13892120',
#    'timestamp': '2012-11-16T09:59:00Z',
#    'uid': '26299',
#    'user': 'uboot',
#    'version': '3'},
#   'id': '50865110',
#   'pos': [40.2669768, -105.5406845],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:06:19Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50865127',
#   'pos': [40.26711, -105.541278],
#   'type': 'node'},
#  {'created': {'changeset': '3106555',
#    'timestamp': '2009-11-13T15:14:19Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50865150',
#   'pos': [40.267249, -105.542184],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:06:20Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50865175',
#   'pos': [40.266522, -105.543761],
#   'type': 'node'},
#  {'created': {'changeset': '31239139',
#    'timestamp': '2015-05-17T20:32:30Z',
#    'uid': '1061145',
#    'user': 'UE_Su',
#    'version': '3'},
#   'id': '50865412',
#   'pos': [40.2792911, -105.3629895],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:06:54Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50867255',
#   'pos': [40.300056, -105.490228],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:06:54Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50867274',
#   'pos': [40.29843, -105.489516],
#   'type': 'node'},
#  {'created': {'changeset': '2488126',
#    'timestamp': '2009-09-15T04:23:03Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50867289',
#   'pos': [40.297195, -105.490941],
#   'type': 'node'},
#  {'created': {'changeset': '2963453',
#    'timestamp': '2009-10-27T09:01:14Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50867308',
#   'pos': [40.296254, -105.492403],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:06:55Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50867327',
#   'pos': [40.29482, -105.49338],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:06:56Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50867345',
#   'pos': [40.292861, -105.493899],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:06:56Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50867363',
#   'pos': [40.293383, -105.492322],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:06:56Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50867381',
#   'pos': [40.29231, -105.491744],
#   'type': 'node'},
#  {'created': {'changeset': '2963453',
#    'timestamp': '2009-10-27T09:01:14Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50867395',
#   'pos': [40.29112, -105.491889],
#   'type': 'node'},
#  {'created': {'changeset': '3106555',
#    'timestamp': '2009-11-13T15:14:43Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50867411',
#   'pos': [40.289832, -105.490104],
#   'type': 'node'},
#  {'created': {'changeset': '2488126',
#    'timestamp': '2009-09-15T04:23:04Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50867425',
#   'pos': [40.288433, -105.489288],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:06:58Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50867435',
#   'pos': [40.286817, -105.48963],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:06:58Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50867445',
#   'pos': [40.285137, -105.487577],
#   'type': 'node'},
#  {'created': {'changeset': '2963453',
#    'timestamp': '2009-10-27T09:01:15Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50867460',
#   'pos': [40.283903, -105.486439],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:06:59Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50867476',
#   'pos': [40.283108, -105.484479],
#   'type': 'node'},
#  {'created': {'changeset': '2488126',
#    'timestamp': '2009-09-15T04:23:04Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50867494',
#   'pos': [40.282645, -105.482588],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:07:00Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50867506',
#   'pos': [40.282591, -105.480286],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:07:00Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50867518',
#   'pos': [40.282121, -105.477934],
#   'type': 'node'},
#  {'created': {'changeset': '2963453',
#    'timestamp': '2009-10-27T09:01:16Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50867531',
#   'pos': [40.281641, -105.475621],
#   'type': 'node'},
#  {'created': {'changeset': '3106555',
#    'timestamp': '2009-11-13T15:14:44Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50867543',
#   'pos': [40.280852, -105.472237],
#   'type': 'node'},
#  {'created': {'changeset': '2488126',
#    'timestamp': '2009-09-15T04:23:04Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50867617',
#   'pos': [40.279149, -105.46927],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:07:01Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50867633',
#   'pos': [40.277319, -105.465702],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:07:02Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50867651',
#   'pos': [40.275516, -105.464138],
#   'type': 'node'},
#  {'created': {'changeset': '2963453',
#    'timestamp': '2009-10-27T09:01:24Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50869769',
#   'pos': [40.262195, -105.530739],
#   'type': 'node'},
#  {'created': {'changeset': '2488126',
#    'timestamp': '2009-09-15T04:23:21Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50874053',
#   'pos': [40.266891, -105.354639],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:08:46Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50874818',
#   'pos': [40.292668, -105.219697],
#   'type': 'node'},
#  {'created': {'changeset': '3106555',
#    'timestamp': '2009-11-13T15:15:05Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50874836',
#   'pos': [40.298673, -105.215597],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:09:06Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50876321',
#   'pos': [40.268056, -105.538431],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:09:06Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50876338',
#   'pos': [40.268641, -105.536665],
#   'type': 'node'},
#  {'created': {'changeset': '3106555',
#    'timestamp': '2009-11-13T15:15:10Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50876355',
#   'pos': [40.268354, -105.535107],
#   'type': 'node'},
#  {'created': {'changeset': '2963453',
#    'timestamp': '2009-10-27T09:01:42Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50876373',
#   'pos': [40.268446, -105.533908],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:09:07Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50876395',
#   'pos': [40.268285, -105.53095],
#   'type': 'node'},
#  {'created': {'changeset': '30814522',
#    'timestamp': '2015-05-05T16:04:52Z',
#    'uid': '191112',
#    'user': 'tekim',
#    'version': '4'},
#   'id': '50876435',
#   'pos': [40.3059448, -105.5382697],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:09:08Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50876455',
#   'pos': [40.304866, -105.540175],
#   'type': 'node'},
#  {'created': {'changeset': '4001208',
#    'timestamp': '2010-02-28T18:35:54Z',
#    'uid': '191112',
#    'user': 'tekim',
#    'version': '3'},
#   'id': '50876471',
#   'pos': [40.305925, -105.5423802],
#   'type': 'node'},
#  {'created': {'changeset': '2963453',
#    'timestamp': '2009-10-27T09:02:18Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50887791',
#   'pos': [40.30493, -105.135035],
#   'type': 'node'},
#  {'created': {'changeset': '2488126',
#    'timestamp': '2009-09-15T04:24:00Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50888723',
#   'pos': [40.285183, -105.072661],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:12:07Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50888741',
#   'pos': [40.28595, -105.070699],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:12:07Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50888757',
#   'pos': [40.286443, -105.069533],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:12:07Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50888775',
#   'pos': [40.286932, -105.067904],
#   'type': 'node'},
#  {'created': {'changeset': '2963453',
#    'timestamp': '2009-10-27T09:02:21Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50888792',
#   'pos': [40.286774, -105.066583],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:12:08Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50888806',
#   'pos': [40.286951, -105.064729],
#   'type': 'node'},
#  {'created': {'changeset': '3106555',
#    'timestamp': '2009-11-13T15:15:47Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50888819',
#   'pos': [40.287949, -105.059496],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:12:08Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50888829',
#   'pos': [40.288698, -105.056484],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:12:09Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50889594',
#   'pos': [40.275287, -105.359316],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:12:12Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50889949',
#   'pos': [40.269171, -105.538402],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:12:12Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50890117',
#   'pos': [40.269316, -105.539988],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:13:05Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50893469',
#   'pos': [40.29531, -105.45411],
#   'type': 'node'},
#  {'created': {'changeset': '2488126',
#    'timestamp': '2009-09-15T04:24:29Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50893505',
#   'pos': [40.297285, -105.453041],
#   'type': 'node'},
#  {'created': {'changeset': '3106555',
#    'timestamp': '2009-11-13T15:15:59Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50893526',
#   'pos': [40.299025, -105.450661],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:13:06Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50893549',
#   'pos': [40.299474, -105.449535],
#   'type': 'node'},
#  {'created': {'changeset': '2963453',
#    'timestamp': '2009-10-27T09:02:50Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50893571',
#   'pos': [40.29941, -105.44732],
#   'type': 'node'},
#  {'created': {'changeset': '3106555',
#    'timestamp': '2009-11-13T15:16:00Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50893594',
#   'pos': [40.301373, -105.446844],
#   'type': 'node'},
#  {'created': {'changeset': '2488126',
#    'timestamp': '2009-09-15T04:24:30Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50893618',
#   'pos': [40.303649, -105.446668],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:13:07Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50893650',
#   'pos': [40.306057, -105.446064],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:13:07Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50893677',
#   'pos': [40.307498, -105.448175],
#   'type': 'node'},
#  {'created': {'changeset': '2963453',
#    'timestamp': '2009-10-27T09:02:51Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50893701',
#   'pos': [40.308568, -105.451649],
#   'type': 'node'},
#  {'created': {'changeset': '3106555',
#    'timestamp': '2009-11-13T15:16:01Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50893821',
#   'pos': [40.284168, -105.267179],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:13:09Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50893849',
#   'pos': [40.280799, -105.267218],
#   'type': 'node'},
#  {'created': {'changeset': '31239139',
#    'timestamp': '2015-05-17T20:52:59Z',
#    'uid': '1061145',
#    'user': 'UE_Su',
#    'version': '3'},
#   'id': '50893867',
#   'pos': [40.2758966, -105.2725408],
#   'type': 'node'},
#  {'created': {'changeset': '31239139',
#    'timestamp': '2015-05-17T20:52:59Z',
#    'uid': '1061145',
#    'user': 'UE_Su',
#    'version': '3'},
#   'id': '50893887',
#   'pos': [40.2733188, -105.2779104],
#   'type': 'node'},
#  {'created': {'changeset': '31239139',
#    'timestamp': '2015-05-17T20:52:59Z',
#    'uid': '1061145',
#    'user': 'UE_Su',
#    'version': '3'},
#   'id': '50893909',
#   'pos': [40.2710887, -105.2795672],
#   'type': 'node'},
#  {'created': {'changeset': '31239139',
#    'timestamp': '2015-05-17T20:53:00Z',
#    'uid': '1061145',
#    'user': 'UE_Su',
#    'version': '3'},
#   'id': '50893933',
#   'pos': [40.2656644, -105.27743],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:14:08Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50900453',
#   'pos': [40.309086, -105.293714],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:14:08Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50900471',
#   'pos': [40.309417, -105.295438],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:14:17Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50901601',
#   'pos': [40.288541, -105.544352],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:14:20Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50901841',
#   'pos': [40.289416, -105.544015],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:15:01Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50904474',
#   'pos': [40.312678, -105.458436],
#   'type': 'node'},
#  {'created': {'changeset': '3106555',
#    'timestamp': '2009-11-13T15:16:29Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50904495',
#   'pos': [40.309656, -105.453067],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:15:02Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50904517',
#   'pos': [40.30791, -105.452691],
#   'type': 'node'},
#  {'created': {'changeset': '2488126',
#    'timestamp': '2009-09-15T04:25:05Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50904537',
#   'pos': [40.306849, -105.451112],
#   'type': 'node'},
#  {'created': {'changeset': '2963453',
#    'timestamp': '2009-10-27T09:03:24Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50904560',
#   'pos': [40.306308, -105.449525],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:15:02Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50904580',
#   'pos': [40.303967, -105.446915],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:15:03Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50904600',
#   'pos': [40.302626, -105.444517],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:15:03Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50904661',
#   'pos': [40.300938, -105.443572],
#   'type': 'node'},
#  {'created': {'changeset': '2488126',
#    'timestamp': '2009-09-15T04:25:05Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50904683',
#   'pos': [40.298474, -105.44279],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:15:04Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50904703',
#   'pos': [40.296953, -105.443225],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:15:04Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50904726',
#   'pos': [40.297898, -105.447553],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:15:09Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50905149',
#   'pos': [40.296524, -105.442278],
#   'type': 'node'},
#  {'created': {'changeset': '2488126',
#    'timestamp': '2009-09-15T04:25:20Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50911139',
#   'pos': [40.290184, -105.19769],
#   'type': 'node'},
#  {'created': {'changeset': '3106555',
#    'timestamp': '2009-11-13T15:16:57Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50911161',
#   'pos': [40.289778, -105.196745],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:15:51Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50911188',
#   'pos': [40.28951, -105.196214],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:15:51Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50911210',
#   'pos': [40.290209, -105.19585],
#   'type': 'node'},
#  {'created': {'changeset': '3106555',
#    'timestamp': '2009-11-13T15:16:57Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50911234',
#   'pos': [40.28937, -105.19544],
#   'type': 'node'},
#  {'created': {'changeset': '2488126',
#    'timestamp': '2009-09-15T04:25:21Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50911256',
#   'pos': [40.288749, -105.194775],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:15:52Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50911280',
#   'pos': [40.289406, -105.194752],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:15:52Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50911304',
#   'pos': [40.288769, -105.193743],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:15:52Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50911328',
#   'pos': [40.289538, -105.193087],
#   'type': 'node'},
#  {'created': {'changeset': '2963453',
#    'timestamp': '2009-10-27T09:03:39Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50911351',
#   'pos': [40.289355, -105.192493],
#   'type': 'node'},
#  {'created': {'changeset': '2963453',
#    'timestamp': '2009-10-27T09:03:39Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50911397',
#   'pos': [40.283427, -105.079649],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:15:53Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '50911421',
#   'pos': [40.282138, -105.081167],
#   'type': 'node'},
#  {'created': {'changeset': '3376945',
#    'timestamp': '2009-12-15T05:15:53Z',
#    'uid': '147510',
# ...
#   'type': 'node'},
#  {'created': {'changeset': '31326313',
#    'timestamp': '2015-05-20T20:19:39Z',
#    'uid': '1061145',
#    'user': 'UE_Su',
#    'version': '3'},
#   'id': '51139546',
#   'pos': [40.2850525, -105.2265586],
#   'type': 'node'},
#  {'created': {'changeset': '3505138',
#    'timestamp': '2010-01-01T03:08:30Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51139559',
#   'pos': [40.287103, -105.226881],
#   'type': 'node'},
#  {'created': {'changeset': '3505138',
#    'timestamp': '2010-01-01T03:08:30Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51139569',
#   'pos': [40.288926, -105.226687],
#   'type': 'node'},
#  {'created': {'changeset': '2488126',
#    'timestamp': '2009-09-15T04:45:13Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51139579',
#   'pos': [40.289221, -105.227314],
#   'type': 'node'},
#  {'created': {'changeset': '2488126',
#    'timestamp': '2009-09-15T04:45:13Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51139592',
#   'pos': [40.290086, -105.228634],
#   'type': 'node'},
#  {'created': {'changeset': '3505138',
#    'timestamp': '2010-01-01T03:08:31Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51139603',
#   'pos': [40.291403, -105.229405],
#   'type': 'node'},
#  {'created': {'changeset': '3505138',
#    'timestamp': '2010-01-01T03:08:32Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51139613',
#   'pos': [40.292838, -105.229318],
#   'type': 'node'},
#  {'created': {'changeset': '3505138',
#    'timestamp': '2010-01-01T03:08:32Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51139623',
#   'pos': [40.294701, -105.228634],
#   'type': 'node'},
#  {'created': {'changeset': '2963453',
#    'timestamp': '2009-10-27T09:25:21Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51139633',
#   'pos': [40.296252, -105.228453],
#   'type': 'node'},
#  {'created': {'changeset': '2488126',
#    'timestamp': '2009-09-15T04:45:14Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51139643',
#   'pos': [40.296797, -105.226221],
#   'type': 'node'},
#  {'created': {'changeset': '3505138',
#    'timestamp': '2010-01-01T03:08:54Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51140342',
#   'pos': [40.284254, -105.354823],
#   'type': 'node'},
#  {'created': {'changeset': '16516392',
#    'timestamp': '2013-06-11T21:13:50Z',
#    'uid': '1538681',
#    'user': 'zdaddyo',
#    'version': '3'},
#   'id': '51140400',
#   'pos': [40.2996784, -105.0760725],
#   'type': 'node'},
#  {'created': {'changeset': '3505138',
#    'timestamp': '2010-01-01T03:09:17Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51141083',
#   'pos': [40.264939, -105.290733],
#   'type': 'node'},
#  {'created': {'changeset': '2488126',
#    'timestamp': '2009-09-15T04:45:23Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51141115',
#   'pos': [40.292193, -105.126106],
#   'type': 'node'},
#  {'created': {'changeset': '3505138',
#    'timestamp': '2010-01-01T03:09:20Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51141125',
#   'pos': [40.293257, -105.134403],
#   'type': 'node'},
#  {'created': {'changeset': '3505138',
#    'timestamp': '2010-01-01T03:09:23Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51141238',
#   'pos': [40.286375, -105.260613],
#   'type': 'node'},
#  {'created': {'changeset': '2963453',
#    'timestamp': '2009-10-27T09:25:34Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51141248',
#   'pos': [40.285564, -105.25946],
#   'type': 'node'},
#  {'created': {'changeset': '2963453',
#    'timestamp': '2009-10-27T09:25:51Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51143634',
#   'pos': [40.280767, -105.364249],
#   'type': 'node'},
#  {'created': {'changeset': '3376987',
#    'timestamp': '2009-12-15T06:02:00Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51144198',
#   'pos': [40.29798, -105.087884],
#   'type': 'node'},
#  {'created': {'changeset': '2963453',
#    'timestamp': '2009-10-27T09:25:56Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51144398',
#   'pos': [40.282012, -105.35247],
#   'type': 'node'},
#  {'created': {'changeset': '3376987',
#    'timestamp': '2009-12-15T06:02:08Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51144414',
#   'pos': [40.281082, -105.352784],
#   'type': 'node'},
#  {'created': {'changeset': '3376987',
#    'timestamp': '2009-12-15T06:02:08Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51144436',
#   'pos': [40.265056, -105.426117],
#   'type': 'node'},
#  {'created': {'changeset': '2488126',
#    'timestamp': '2009-09-15T04:45:47Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51145171',
#   'pos': [40.271102, -105.318335],
#   'type': 'node'},
#  {'created': {'changeset': '3376987',
#    'timestamp': '2009-12-15T06:02:40Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51145182',
#   'pos': [40.271945, -105.318172],
#   'type': 'node'},
#  {'created': {'changeset': '3376987',
#    'timestamp': '2009-12-15T06:02:42Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51145252',
#   'pos': [40.312596, -105.204004],
#   'type': 'node'},
#  {'created': {'changeset': '3376987',
#    'timestamp': '2009-12-15T06:02:43Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51145263',
#   'pos': [40.31056, -105.204249],
#   'type': 'node'},
#  {'created': {'changeset': '3376987',
#    'timestamp': '2009-12-15T06:02:43Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51145275',
#   'pos': [40.309368, -105.203827],
#   'type': 'node'},
#  {'created': {'changeset': '2488126',
#    'timestamp': '2009-09-15T04:45:48Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51145285',
#   'pos': [40.308006, -105.202634],
#   'type': 'node'},
#  {'created': {'changeset': '3376987',
#    'timestamp': '2009-12-15T06:02:45Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51145295',
#   'pos': [40.305858, -105.202452],
#   'type': 'node'},
#  {'created': {'changeset': '3376987',
#    'timestamp': '2009-12-15T06:03:00Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51145305',
#   'pos': [40.302222, -105.203223],
#   'type': 'node'},
#  {'created': {'changeset': '2963453',
#    'timestamp': '2009-10-27T09:26:04Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51145315',
#   'pos': [40.299419, -105.202186],
#   'type': 'node'},
#  {'created': {'changeset': '3376987',
#    'timestamp': '2009-12-15T06:03:01Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51145325',
#   'pos': [40.297321, -105.200797],
#   'type': 'node'},
#  {'created': {'changeset': '3376987',
#    'timestamp': '2009-12-15T06:03:02Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51145336',
#   'pos': [40.29642, -105.200481],
#   'type': 'node'},
#  {'created': {'changeset': '3376987',
#    'timestamp': '2009-12-15T06:03:02Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51145346',
#   'pos': [40.295126, -105.201335],
#   'type': 'node'},
#  {'created': {'changeset': '3376987',
#    'timestamp': '2009-12-15T06:03:02Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51145356',
#   'pos': [40.294337, -105.201985],
#   'type': 'node'},
#  {'created': {'changeset': '2488126',
#    'timestamp': '2009-09-15T04:45:48Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51145366',
#   'pos': [40.292761, -105.202478],
#   'type': 'node'},
#  {'created': {'changeset': '3376987',
#    'timestamp': '2009-12-15T06:03:03Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51145376',
#   'pos': [40.290596, -105.202759],
#   'type': 'node'},
#  {'created': {'changeset': '3376987',
#    'timestamp': '2009-12-15T06:03:04Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51145386',
#   'pos': [40.288814, -105.202973],
#   'type': 'node'},
#  {'created': {'changeset': '2963453',
#    'timestamp': '2009-10-27T09:26:04Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51145396',
#   'pos': [40.284114, -105.203585],
#   'type': 'node'},
#  {'created': {'changeset': '3376987',
#    'timestamp': '2009-12-15T06:03:05Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51145406',
#   'pos': [40.282827, -105.205424],
#   'type': 'node'},
#  {'created': {'changeset': '2488126',
#    'timestamp': '2009-09-15T04:45:48Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51145416',
#   'pos': [40.280824, -105.205122],
#   'type': 'node'},
#  {'created': {'changeset': '3376987',
#    'timestamp': '2009-12-15T06:03:06Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51145426',
#   'pos': [40.277919, -105.206078],
#   'type': 'node'},
#  {'created': {'changeset': '3376987',
#    'timestamp': '2009-12-15T06:03:06Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51145436',
#   'pos': [40.275173, -105.206156],
#   'type': 'node'},
#  {'created': {'changeset': '2963453',
#    'timestamp': '2009-10-27T09:26:05Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51145446',
#   'pos': [40.273003, -105.20676],
#   'type': 'node'},
#  {'created': {'changeset': '3376987',
#    'timestamp': '2009-12-15T06:03:07Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51145456',
#   'pos': [40.271195, -105.206495],
#   'type': 'node'},
#  {'created': {'changeset': '2963453',
#    'timestamp': '2009-10-27T09:26:05Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51145466',
#   'pos': [40.269457, -105.206486],
#   'type': 'node'},
#  {'created': {'changeset': '3376987',
#    'timestamp': '2009-12-15T06:03:08Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51145476',
#   'pos': [40.268034, -105.205653],
#   'type': 'node'},
#  {'created': {'changeset': '3376987',
#    'timestamp': '2009-12-15T06:03:09Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51145486',
#   'pos': [40.265712, -105.2063],
#   'type': 'node'},
#  {'created': {'changeset': '2488126',
#    'timestamp': '2009-09-15T04:45:49Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51145496',
#   'pos': [40.264793, -105.207265],
#   'type': 'node'},
#  {'created': {'changeset': '3376987',
#    'timestamp': '2009-12-15T06:03:10Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51145506',
#   'pos': [40.261607, -105.208255],
#   'type': 'node'},
#  {'created': {'changeset': '3376987',
#    'timestamp': '2009-12-15T06:03:27Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51145846',
#   'pos': [40.292552, -105.1376],
#   'type': 'node'},
#  {'created': {'changeset': '2488126',
#    'timestamp': '2009-09-15T04:46:01Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51147062',
#   'pos': [40.308554, -105.168973],
#   'type': 'node'},
#  {'created': {'changeset': '3376987',
#    'timestamp': '2009-12-15T06:04:21Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51147072',
#   'pos': [40.310121, -105.170852],
#   'type': 'node'},
#  {'created': {'changeset': '3376987',
#    'timestamp': '2009-12-15T06:04:21Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51147082',
#   'pos': [40.311047, -105.173672],
#   'type': 'node'},
#  {'created': {'changeset': '2488126',
#    'timestamp': '2009-09-15T04:46:30Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51148907',
#   'pos': [40.260125, -105.421103],
#   'type': 'node'},
#  {'created': {'changeset': '3376987',
#    'timestamp': '2009-12-15T06:06:12Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51148917',
#   'pos': [40.258415, -105.420433],
#   'type': 'node'},
#  {'created': {'changeset': '3376987',
#    'timestamp': '2009-12-15T06:06:12Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51148927',
#   'pos': [40.258892, -105.419415],
#   'type': 'node'},
#  {'created': {'changeset': '2963453',
#    'timestamp': '2009-10-27T09:26:51Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51148937',
#   'pos': [40.25938, -105.416115],
#   'type': 'node'},
#  {'created': {'changeset': '3376987',
#    'timestamp': '2009-12-15T06:06:13Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51148947',
#   'pos': [40.260634, -105.414031],
#   'type': 'node'},
#  {'created': {'changeset': '2488126',
#    'timestamp': '2009-09-15T04:46:30Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51148957',
#   'pos': [40.260635, -105.412575],
#   'type': 'node'},
#  {'created': {'changeset': '3376987',
#    'timestamp': '2009-12-15T06:06:14Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51148967',
#   'pos': [40.260777, -105.410561],
#   'type': 'node'},
#  {'created': {'changeset': '3376987',
#    'timestamp': '2009-12-15T06:06:14Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51148977',
#   'pos': [40.260992, -105.408432],
#   'type': 'node'},
#  {'created': {'changeset': '2963453',
#    'timestamp': '2009-10-27T09:26:52Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51148987',
#   'pos': [40.259877, -105.407484],
#   'type': 'node'},
#  {'created': {'changeset': '3376987',
#    'timestamp': '2009-12-15T06:06:15Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51148997',
#   'pos': [40.258131, -105.407666],
#   'type': 'node'},
#  {'created': {'changeset': '3376987',
#    'timestamp': '2009-12-15T06:06:18Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51149113',
#   'pos': [40.302096, -105.228318],
#   'type': 'node'},
#  {'created': {'changeset': '3376987',
#    'timestamp': '2009-12-15T06:06:37Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51149512',
#   'pos': [40.261233, -105.168068],
#   'type': 'node'},
#  {'created': {'changeset': '2488126',
#    'timestamp': '2009-09-15T04:46:34Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51149522',
#   'pos': [40.261164, -105.163768],
#   'type': 'node'},
#  {'created': {'changeset': '3376987',
#    'timestamp': '2009-12-15T06:06:39Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51149532',
#   'pos': [40.261183, -105.162637],
#   'type': 'node'},
#  {'created': {'changeset': '3376987',
#    'timestamp': '2009-12-15T06:06:39Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51149542',
#   'pos': [40.261213, -105.159894],
#   'type': 'node'},
#  {'created': {'changeset': '16516062',
#    'timestamp': '2013-06-11T20:42:32Z',
#    'uid': '1538681',
#    'user': 'zdaddyo',
#    'version': '3'},
#   'id': '51149644',
#   'pos': [40.3009118, -105.0785235],
#   'type': 'node'},
#  {'created': {'changeset': '34978199',
#    'timestamp': '2015-10-30T18:22:17Z',
#    'uid': '2429366',
#    'user': 'Didger85',
#    'version': '5'},
#   'id': '51156265',
#   'pos': [40.3051231, -105.0837439],
#   'type': 'node'},
#  {'created': {'changeset': '3376987',
#    'timestamp': '2009-12-15T06:13:54Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '51157104',
#   'pos': [40.268495, -105.353415],
#   'type': 'node'},
#  ...]

# %%
data[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-88cae4a5bf31> in <module>()
# ----> 1 data[0]
#
# NameError: name 'data' is not defined
